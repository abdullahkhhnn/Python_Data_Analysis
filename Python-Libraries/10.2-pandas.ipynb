# %% [markdown]
# #### Pandas-DataFrame And Series
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
import pandas as pd

# %%
## Series
##A Pandas Series is a one-dimensional array-like object that can hold any data type. It is similar to a column in a table.

import pandas as pd
data=[1,2,3,4,5]
series=pd.Series(data)
print("Series \n",series)
print(type(series))

# %%
## Create a Series from dictionary
data={'a':1,'b':2,'c':3}
series_dict=pd.Series(data)
print(series_dict)

# %%
data=[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)

# %%
## Dataframe
## create a Dataframe from a dictionary of list

data= {
    'Name': ['Abdullah','Faizan','Hadi'],
    'Age': [24,18,22],
    'City': ['Mardan', 'Swat','Tirah']
}

df=pd.DataFrame(data)
print(df)
print(type(df))

# %%
df=pd.read_csv("data.csv")
df.head(10)

# %%
df.tail(10)

# %%
### Accessing Data From Dataframe
df

# %%
df['Category']

# %%
## row index
df.loc[0]

# %%
## column index
df.iloc[0]

# %%
df

# %%
## Accessing a specified element
df.at[2,'Region']

# %%
df.at[2,'Sales']

# %%
## Accessing a specified element using iat
df.iat[2,2]

# %%
df

# %%
### Data MAnipulation with Dataframe
df

# %%
## Adding a column
## add 50 names

df['Name']=['Abdullah','Faizan','Hadi']
df

# %%
## Remove a column
df.drop('Name',axis=1,inplace=True)

# %%
df

# %%
## Add age to the column
df['Age']=df['Age']+1
df

# %%
df.drop(0,inplace=True)

# %%
df

# %%
df=pd.read_csv('data.csv')
df.head(5)

# %%
# Display the data types of each column
print("Data types:\n", df.dtypes)

# Describe the DataFrame (statistical summary)
print("Statistical summary:\n", df.describe())
# Out:
# Data types:
#  Date                 object
# Category             object
# Value               float64
# Product Category     object
# Sales               float64
# Region               object
# Price per Unit        int64
# Total Amount          int64
# dtype: object
# Statistical summary:
#             Value       Sales  Price per Unit  Total Amount
# count  47.000000   46.000000       50.000000     50.000000
# mean   51.744681  557.130435      186.300000    449.400000
# std    29.050532  274.598584      191.326759    514.223845
# min     2.000000  108.000000       25.000000     25.000000
# 25%    27.500000  339.000000       30.000000     75.000000
# 50%    54.000000  591.500000       50.000000    135.000000
# 75%    70.000000  767.500000      300.000000    900.000000
# max    99.000000  992.000000      500.000000   2000.000000
